# %% [markdown]
# # Chapter 6.5
#
# In this notebook, we tackle the problem of portfolio optimizatio from the perspective of deep learning. We introduce an end-to-end framework that utilizes deep learning models to directly optimize a portfolio.

# %%
import os 
import sys
current_dir = os.path.dirname(os.path.abspath("__file__"))
project_dir = os.path.dirname(current_dir)
sys.path.append(project_dir)

import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch.optim as optim
import torch.nn as nn

from Utilis.early_stopper import EarlyStopping
from Utilis.metrics import report_metrics
from Utilis.torch_data import MyDataset
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
def read_data(data_path):
    df = pd.read_csv(data_path)
    df.index = pd.to_datetime(df['Date'])
    df = df.drop(columns=['Date'])
    train_data = df[:'2017']
    val_data = pd.concat((df.loc["2018"], df.loc['2019']))
    test_data = pd.concat((df.loc["2020"], df.loc['2022':]))
    return train_data, val_data, test_data
    
def data_classification(X, k, T):
    [N, D] = X.shape
    df = np.array(X)
    dataX = np.zeros((N - T + 1, T, D))
    for i in range(T, N + 1):
        dataX[i - T] = df[i - T:i, :]
    return dataX[:-k]

def prepare_y(data, k, T):
    return np.array(data[T-1 + k:])

# %%
def Neg_Sharpe(portfolio):
    return -torch.mean(portfolio)/torch.std(portfolio)

class Utility(torch.nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, outputs, future_rets):
        portflio = outputs * future_rets 
        portflio = torch.sum(portflio, dim=1)
        loss = Neg_Sharpe(portflio)
        return loss

class MLP(nn.Module):
    def __init__(self, seq_length, n_features, y_dim):
        super().__init__()

        self.fc = nn.Sequential(
            nn.Flatten(),       
            nn.Linear(seq_length*n_features, 4),
            nn.Tanh(),
            nn.Linear(4, y_dim))

    def forward(self, x):
        x = torch.flatten(x, start_dim=1)
        x = self.fc(x)
        y = torch.softmax(x, dim=1)   #long only
        return y   


def train_model(model, train_data_loader, val_data_loader, X_test, savepath, epochs=5, lr=1e-3, patience=5):
    optimizer = optim.Adam(model.parameters(), lr=lr)
    criterion = Utility()
    early_stopper = EarlyStopping(savepath=savepath, patience=patience, min_delta=1e-4, verbose=True)
    for epoch in range(epochs):
        train_epoch_loss = []
        val_epoch_loss = []
        
        model.train()
        for batch_X, batch_y in train_data_loader:
            optimizer.zero_grad()
            out = model(batch_X)
            loss = criterion(out, batch_y)
            loss.backward()
            optimizer.step()
            train_epoch_loss.append(loss.item())

        model.eval()
        for batch_X, batch_y in val_data_loader:
            with torch.no_grad():
                out = model(batch_X)
                loss = criterion(out, batch_y)
                val_epoch_loss.append(loss.item())
        
        train_epoch_loss = np.mean(train_epoch_loss)
        val_epoch_loss = np.mean(val_epoch_loss)

        print(f"Epoch {epoch+1}/{epochs}, "
              f"Train loss: {train_epoch_loss:.4f}, "
              f"Validation loss: {val_epoch_loss:.4f}")
        
        early_stopper(model, val_epoch_loss)
        if early_stopper.early_stop:
            print("Early stopping triggered!")
            break
    
    model.load_state_dict(torch.load(savepath))
    model.eval()
    y_pred_test = model(torch.from_numpy(X_test.astype(np.float32)))
    return model, y_pred_test.detach().cpu().numpy()

# %%
data_path = '../Data/portfolio_data.csv'
T = 10
k = 1

# %%
ticker_list = ['AXP', 'CI', 'GD', 'HON', 'MMM',
              'MO', 'MRK', 'PFE', 'PG', 'SO', 
              'NEM', 'NSC', 'GE', 'AEP', 'AAPL', 
              'ABT', 'SNA', 'PTC', 'BAC', 'NKE'] 

train_data, val_data, test_data = read_data('../Data/portfolio_data.csv')

# %%
train_x = data_classification(train_data[[tic + '_Return' for tic in ticker_list]], k, T)
train_y = prepare_y(train_data[[tic + '_Return' for tic in ticker_list]], k, T)

val_x = data_classification(val_data[[tic + '_Return' for tic in ticker_list]], k, T)
val_y = prepare_y(val_data[[tic + '_Return' for tic in ticker_list]], k, T)

test_x = data_classification(test_data[[tic + '_Return' for tic in ticker_list]], k, T)
test_y = prepare_y(test_data[[tic + '_Return' for tic in ticker_list]], k, T)

print(train_x.shape, train_y.shape)
print(val_x.shape, val_y.shape)
print(test_x.shape, test_y.shape)
# Out:
# (6311, 10, 20) (6311, 20)
# (493, 10, 20) (493, 20)
# (469, 10, 20) (469, 20)

# %%
train_loader = torch.utils.data.DataLoader(dataset=MyDataset(train_x, train_y), batch_size=512, shuffle=True)
val_loader = torch.utils.data.DataLoader(dataset=MyDataset(val_x, val_y), batch_size=512, shuffle=False)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

model = MLP(T, len(ticker_list), y_dim = len(ticker_list))
model.to(device)
model, y_pred = train_model(model, train_loader, val_loader, test_x, savepath='./model/best_mlp', epochs=1000, lr=0.001, patience=50)
# Out:
# Using device: cpu
# Epoch 1/1000, Train loss: -0.0591, Validation loss: -0.0550
# Epoch 2/1000, Train loss: -0.0549, Validation loss: -0.0550
# No improvement in validation loss. Counter: 1/50
# Epoch 3/1000, Train loss: -0.0628, Validation loss: -0.0549
# No improvement in validation loss. Counter: 2/50
# Epoch 4/1000, Train loss: -0.0573, Validation loss: -0.0550
# No improvement in validation loss. Counter: 3/50
# Epoch 5/1000, Train loss: -0.0533, Validation loss: -0.0550
# No improvement in validation loss. Counter: 4/50
# Epoch 6/1000, Train loss: -0.0607, Validation loss: -0.0550
# No improvement in validation loss. Counter: 5/50
# Epoch 7/1000, Train loss: -0.0579, Validation loss: -0.0550
# No improvement in validation loss. Counter: 6/50
# Epoch 8/1000, Train loss: -0.0632, Validation loss: -0.0550
# No improvement in validation loss. Counter: 7/50
# Epoch 9/1000, Train loss: -0.0630, Validation loss: -0.0550
# No improvement in validation loss. Counter: 8/50
# Epoch 10/1000, Train loss: -0.0606, Validation loss: -0.0550
# No improvement in validation loss. Counter: 9/50
# Epoch 11/1000, Train loss: -0.0529, Validation loss: -0.0550
# No improvement in validation loss. Counter: 10/50
# Epoch 12/1000, Train loss: -0.0560, Validation loss: -0.0550
# No improvement in validation loss. Counter: 11/50
# Epoch 13/1000, Train loss: -0.0587, Validation loss: -0.0550
# No improvement in validation loss. Counter: 12/50
# Epoch 14/1000, Train loss: -0.0652, Validation loss: -0.0551
# No improvement in validation loss. Counter: 13/50
# Epoch 15/1000, Train loss: -0.0723, Validation loss: -0.0551
# No improvement in validation loss. Counter: 14/50
# Epoch 16/1000, Train loss: -0.0608, Validation loss: -0.0550
# No improvement in validation loss. Counter: 15/50
# Epoch 17/1000, Train loss: -0.0650, Validation loss: -0.0551
# No improvement in validation loss. Counter: 16/50
# Epoch 18/1000, Train loss: -0.0637, Validation loss: -0.0551
# No improvement in validation loss. Counter: 17/50
# Epoch 19/1000, Train loss: -0.0576, Validation loss: -0.0550
# No improvement in validation loss. Counter: 18/50
# Epoch 20/1000, Train loss: -0.0646, Validation loss: -0.0550
# No improvement in validation loss. Counter: 19/50
# Epoch 21/1000, Train loss: -0.0688, Validation loss: -0.0551
# No improvement in validation loss. Counter: 20/50
# Epoch 22/1000, Train loss: -0.0682, Validation loss: -0.0551
# No improvement in validation loss. Counter: 21/50
# Epoch 23/1000, Train loss: -0.0603, Validation loss: -0.0551
# No improvement in validation loss. Counter: 22/50
# Epoch 24/1000, Train loss: -0.0677, Validation loss: -0.0551
# Validation loss improved. Resetting counter.
# Epoch 25/1000, Train loss: -0.0697, Validation loss: -0.0552
# No improvement in validation loss. Counter: 1/50
# Epoch 26/1000, Train loss: -0.0702, Validation loss: -0.0552
# Validation loss improved. Resetting counter.
# Epoch 27/1000, Train loss: -0.0679, Validation loss: -0.0553
# No improvement in validation loss. Counter: 1/50
# Epoch 28/1000, Train loss: -0.0767, Validation loss: -0.0553
# No improvement in validation loss. Counter: 2/50
# Epoch 29/1000, Train loss: -0.0732, Validation loss: -0.0553
# Validation loss improved. Resetting counter.
# Epoch 30/1000, Train loss: -0.0795, Validation loss: -0.0554
# No improvement in validation loss. Counter: 1/50
# Epoch 31/1000, Train loss: -0.0725, Validation loss: -0.0554
# No improvement in validation loss. Counter: 2/50
# Epoch 32/1000, Train loss: -0.0714, Validation loss: -0.0553
# No improvement in validation loss. Counter: 3/50
# Epoch 33/1000, Train loss: -0.0614, Validation loss: -0.0554
# No improvement in validation loss. Counter: 4/50
# Epoch 34/1000, Train loss: -0.0764, Validation loss: -0.0554
# No improvement in validation loss. Counter: 5/50
# Epoch 35/1000, Train loss: -0.0725, Validation loss: -0.0554
# No improvement in validation loss. Counter: 6/50
# Epoch 36/1000, Train loss: -0.0688, Validation loss: -0.0555
# Validation loss improved. Resetting counter.
# Epoch 37/1000, Train loss: -0.0853, Validation loss: -0.0556
# Validation loss improved. Resetting counter.
# Epoch 38/1000, Train loss: -0.0777, Validation loss: -0.0556
# No improvement in validation loss. Counter: 1/50
# Epoch 39/1000, Train loss: -0.0758, Validation loss: -0.0557
# Validation loss improved. Resetting counter.
# Epoch 40/1000, Train loss: -0.0730, Validation loss: -0.0557
# No improvement in validation loss. Counter: 1/50
# Epoch 41/1000, Train loss: -0.0698, Validation loss: -0.0557
# No improvement in validation loss. Counter: 2/50
# Epoch 42/1000, Train loss: -0.0732, Validation loss: -0.0557
# No improvement in validation loss. Counter: 3/50
# Epoch 43/1000, Train loss: -0.0771, Validation loss: -0.0558
# No improvement in validation loss. Counter: 4/50
# Epoch 44/1000, Train loss: -0.0689, Validation loss: -0.0557
# No improvement in validation loss. Counter: 5/50
# Epoch 45/1000, Train loss: -0.0805, Validation loss: -0.0558
# No improvement in validation loss. Counter: 6/50
# Epoch 46/1000, Train loss: -0.0754, Validation loss: -0.0557
# No improvement in validation loss. Counter: 7/50
# Epoch 47/1000, Train loss: -0.0865, Validation loss: -0.0558
# No improvement in validation loss. Counter: 8/50
# Epoch 48/1000, Train loss: -0.0837, Validation loss: -0.0558
# No improvement in validation loss. Counter: 9/50
# Epoch 49/1000, Train loss: -0.0894, Validation loss: -0.0556
# No improvement in validation loss. Counter: 10/50
# Epoch 50/1000, Train loss: -0.0866, Validation loss: -0.0556
# No improvement in validation loss. Counter: 11/50
# Epoch 51/1000, Train loss: -0.0912, Validation loss: -0.0556
# No improvement in validation loss. Counter: 12/50
# Epoch 52/1000, Train loss: -0.0928, Validation loss: -0.0556
# No improvement in validation loss. Counter: 13/50
# Epoch 53/1000, Train loss: -0.0853, Validation loss: -0.0556
# No improvement in validation loss. Counter: 14/50
# Epoch 54/1000, Train loss: -0.0829, Validation loss: -0.0558
# No improvement in validation loss. Counter: 15/50
# Epoch 55/1000, Train loss: -0.0850, Validation loss: -0.0558
# Validation loss improved. Resetting counter.
# Epoch 56/1000, Train loss: -0.0883, Validation loss: -0.0560
# Validation loss improved. Resetting counter.
# Epoch 57/1000, Train loss: -0.0884, Validation loss: -0.0560
# No improvement in validation loss. Counter: 1/50
# Epoch 58/1000, Train loss: -0.0877, Validation loss: -0.0563
# Validation loss improved. Resetting counter.
# Epoch 59/1000, Train loss: -0.0961, Validation loss: -0.0565
# Validation loss improved. Resetting counter.
# Epoch 60/1000, Train loss: -0.0988, Validation loss: -0.0565
# No improvement in validation loss. Counter: 1/50
# Epoch 61/1000, Train loss: -0.0969, Validation loss: -0.0568
# Validation loss improved. Resetting counter.
# Epoch 62/1000, Train loss: -0.0979, Validation loss: -0.0570
# Validation loss improved. Resetting counter.
# Epoch 63/1000, Train loss: -0.0979, Validation loss: -0.0568
# No improvement in validation loss. Counter: 1/50
# Epoch 64/1000, Train loss: -0.0961, Validation loss: -0.0571
# No improvement in validation loss. Counter: 2/50
# Epoch 65/1000, Train loss: -0.0960, Validation loss: -0.0573
# Validation loss improved. Resetting counter.
# Epoch 66/1000, Train loss: -0.0986, Validation loss: -0.0572
# No improvement in validation loss. Counter: 1/50
# Epoch 67/1000, Train loss: -0.1047, Validation loss: -0.0574
# No improvement in validation loss. Counter: 2/50
# Epoch 68/1000, Train loss: -0.0969, Validation loss: -0.0573
# No improvement in validation loss. Counter: 3/50
# Epoch 69/1000, Train loss: -0.0995, Validation loss: -0.0574
# No improvement in validation loss. Counter: 4/50
# Epoch 70/1000, Train loss: -0.1025, Validation loss: -0.0574
# No improvement in validation loss. Counter: 5/50
# Epoch 71/1000, Train loss: -0.1011, Validation loss: -0.0577
# Validation loss improved. Resetting counter.
# Epoch 72/1000, Train loss: -0.1148, Validation loss: -0.0577
# No improvement in validation loss. Counter: 1/50
# Epoch 73/1000, Train loss: -0.1040, Validation loss: -0.0576
# No improvement in validation loss. Counter: 2/50
# Epoch 74/1000, Train loss: -0.1054, Validation loss: -0.0574
# No improvement in validation loss. Counter: 3/50
# Epoch 75/1000, Train loss: -0.1119, Validation loss: -0.0573
# No improvement in validation loss. Counter: 4/50
# Epoch 76/1000, Train loss: -0.1110, Validation loss: -0.0573
# No improvement in validation loss. Counter: 5/50
# Epoch 77/1000, Train loss: -0.1247, Validation loss: -0.0575
# No improvement in validation loss. Counter: 6/50
# Epoch 78/1000, Train loss: -0.1162, Validation loss: -0.0578
# Validation loss improved. Resetting counter.
# Epoch 79/1000, Train loss: -0.1174, Validation loss: -0.0577
# No improvement in validation loss. Counter: 1/50
# Epoch 80/1000, Train loss: -0.1145, Validation loss: -0.0580
# Validation loss improved. Resetting counter.
# Epoch 81/1000, Train loss: -0.1196, Validation loss: -0.0579
# No improvement in validation loss. Counter: 1/50
# Epoch 82/1000, Train loss: -0.1126, Validation loss: -0.0582
# Validation loss improved. Resetting counter.
# Epoch 83/1000, Train loss: -0.1225, Validation loss: -0.0585
# Validation loss improved. Resetting counter.
# Epoch 84/1000, Train loss: -0.1261, Validation loss: -0.0586
# Validation loss improved. Resetting counter.
# Epoch 85/1000, Train loss: -0.1157, Validation loss: -0.0588
# Validation loss improved. Resetting counter.
# Epoch 86/1000, Train loss: -0.1238, Validation loss: -0.0588
# No improvement in validation loss. Counter: 1/50
# Epoch 87/1000, Train loss: -0.1255, Validation loss: -0.0590
# Validation loss improved. Resetting counter.
# Epoch 88/1000, Train loss: -0.1285, Validation loss: -0.0587
# No improvement in validation loss. Counter: 1/50
# Epoch 89/1000, Train loss: -0.1295, Validation loss: -0.0586
# No improvement in validation loss. Counter: 2/50
# Epoch 90/1000, Train loss: -0.1277, Validation loss: -0.0586
# No improvement in validation loss. Counter: 3/50
# Epoch 91/1000, Train loss: -0.1197, Validation loss: -0.0583
# No improvement in validation loss. Counter: 4/50
# Epoch 92/1000, Train loss: -0.1290, Validation loss: -0.0581
# No improvement in validation loss. Counter: 5/50
# Epoch 93/1000, Train loss: -0.1230, Validation loss: -0.0580
# No improvement in validation loss. Counter: 6/50
# Epoch 94/1000, Train loss: -0.1326, Validation loss: -0.0579
# No improvement in validation loss. Counter: 7/50
# Epoch 95/1000, Train loss: -0.1338, Validation loss: -0.0580
# No improvement in validation loss. Counter: 8/50
# Epoch 96/1000, Train loss: -0.1279, Validation loss: -0.0577
# No improvement in validation loss. Counter: 9/50
# Epoch 97/1000, Train loss: -0.1309, Validation loss: -0.0579
# No improvement in validation loss. Counter: 10/50
# Epoch 98/1000, Train loss: -0.1328, Validation loss: -0.0578
# No improvement in validation loss. Counter: 11/50
# Epoch 99/1000, Train loss: -0.1304, Validation loss: -0.0579
# No improvement in validation loss. Counter: 12/50
# Epoch 100/1000, Train loss: -0.1269, Validation loss: -0.0577
# No improvement in validation loss. Counter: 13/50
# Epoch 101/1000, Train loss: -0.1426, Validation loss: -0.0580
# No improvement in validation loss. Counter: 14/50
# Epoch 102/1000, Train loss: -0.1361, Validation loss: -0.0579
# No improvement in validation loss. Counter: 15/50
# Epoch 103/1000, Train loss: -0.1381, Validation loss: -0.0581
# No improvement in validation loss. Counter: 16/50
# Epoch 104/1000, Train loss: -0.1366, Validation loss: -0.0582
# No improvement in validation loss. Counter: 17/50
# Epoch 105/1000, Train loss: -0.1353, Validation loss: -0.0581
# No improvement in validation loss. Counter: 18/50
# Epoch 106/1000, Train loss: -0.1490, Validation loss: -0.0581
# No improvement in validation loss. Counter: 19/50
# Epoch 107/1000, Train loss: -0.1413, Validation loss: -0.0581
# No improvement in validation loss. Counter: 20/50
# Epoch 108/1000, Train loss: -0.1328, Validation loss: -0.0581
# No improvement in validation loss. Counter: 21/50
# Epoch 109/1000, Train loss: -0.1446, Validation loss: -0.0580
# No improvement in validation loss. Counter: 22/50
# Epoch 110/1000, Train loss: -0.1453, Validation loss: -0.0582
# No improvement in validation loss. Counter: 23/50
# Epoch 111/1000, Train loss: -0.1403, Validation loss: -0.0584
# No improvement in validation loss. Counter: 24/50
# Epoch 112/1000, Train loss: -0.1437, Validation loss: -0.0585
# No improvement in validation loss. Counter: 25/50
# Epoch 113/1000, Train loss: -0.1497, Validation loss: -0.0591
# Validation loss improved. Resetting counter.
# Epoch 114/1000, Train loss: -0.1396, Validation loss: -0.0589
# No improvement in validation loss. Counter: 1/50
# Epoch 115/1000, Train loss: -0.1523, Validation loss: -0.0587
# No improvement in validation loss. Counter: 2/50
# Epoch 116/1000, Train loss: -0.1443, Validation loss: -0.0585
# No improvement in validation loss. Counter: 3/50
# Epoch 117/1000, Train loss: -0.1453, Validation loss: -0.0583
# No improvement in validation loss. Counter: 4/50
# Epoch 118/1000, Train loss: -0.1466, Validation loss: -0.0587
# No improvement in validation loss. Counter: 5/50
# Epoch 119/1000, Train loss: -0.1469, Validation loss: -0.0590
# No improvement in validation loss. Counter: 6/50
# Epoch 120/1000, Train loss: -0.1474, Validation loss: -0.0591
# No improvement in validation loss. Counter: 7/50
# Epoch 121/1000, Train loss: -0.1499, Validation loss: -0.0588
# No improvement in validation loss. Counter: 8/50
# Epoch 122/1000, Train loss: -0.1567, Validation loss: -0.0586
# No improvement in validation loss. Counter: 9/50
# Epoch 123/1000, Train loss: -0.1538, Validation loss: -0.0587
# No improvement in validation loss. Counter: 10/50
# Epoch 124/1000, Train loss: -0.1568, Validation loss: -0.0585
# No improvement in validation loss. Counter: 11/50
# Epoch 125/1000, Train loss: -0.1576, Validation loss: -0.0588
# No improvement in validation loss. Counter: 12/50
# Epoch 126/1000, Train loss: -0.1579, Validation loss: -0.0587
# No improvement in validation loss. Counter: 13/50
# Epoch 127/1000, Train loss: -0.1592, Validation loss: -0.0588
# No improvement in validation loss. Counter: 14/50
# Epoch 128/1000, Train loss: -0.1555, Validation loss: -0.0591
# No improvement in validation loss. Counter: 15/50
# Epoch 129/1000, Train loss: -0.1559, Validation loss: -0.0589
# No improvement in validation loss. Counter: 16/50
# Epoch 130/1000, Train loss: -0.1568, Validation loss: -0.0592
# No improvement in validation loss. Counter: 17/50
# Epoch 131/1000, Train loss: -0.1543, Validation loss: -0.0591
# No improvement in validation loss. Counter: 18/50
# Epoch 132/1000, Train loss: -0.1556, Validation loss: -0.0593
# Validation loss improved. Resetting counter.
# Epoch 133/1000, Train loss: -0.1636, Validation loss: -0.0596
# Validation loss improved. Resetting counter.
# Epoch 134/1000, Train loss: -0.1603, Validation loss: -0.0595
# No improvement in validation loss. Counter: 1/50
# Epoch 135/1000, Train loss: -0.1617, Validation loss: -0.0592
# No improvement in validation loss. Counter: 2/50
# Epoch 136/1000, Train loss: -0.1622, Validation loss: -0.0590
# No improvement in validation loss. Counter: 3/50
# Epoch 137/1000, Train loss: -0.1593, Validation loss: -0.0590
# No improvement in validation loss. Counter: 4/50
# Epoch 138/1000, Train loss: -0.1644, Validation loss: -0.0588
# No improvement in validation loss. Counter: 5/50
# Epoch 139/1000, Train loss: -0.1603, Validation loss: -0.0589
# No improvement in validation loss. Counter: 6/50
# Epoch 140/1000, Train loss: -0.1611, Validation loss: -0.0589
# No improvement in validation loss. Counter: 7/50
# Epoch 141/1000, Train loss: -0.1613, Validation loss: -0.0590
# No improvement in validation loss. Counter: 8/50
# Epoch 142/1000, Train loss: -0.1624, Validation loss: -0.0590
# No improvement in validation loss. Counter: 9/50
# Epoch 143/1000, Train loss: -0.1597, Validation loss: -0.0584
# No improvement in validation loss. Counter: 10/50
# Epoch 144/1000, Train loss: -0.1719, Validation loss: -0.0584
# No improvement in validation loss. Counter: 11/50
# Epoch 145/1000, Train loss: -0.1698, Validation loss: -0.0582
# No improvement in validation loss. Counter: 12/50
# Epoch 146/1000, Train loss: -0.1710, Validation loss: -0.0581
# No improvement in validation loss. Counter: 13/50
# Epoch 147/1000, Train loss: -0.1648, Validation loss: -0.0582
# No improvement in validation loss. Counter: 14/50
# Epoch 148/1000, Train loss: -0.1632, Validation loss: -0.0582
# No improvement in validation loss. Counter: 15/50
# Epoch 149/1000, Train loss: -0.1663, Validation loss: -0.0585
# No improvement in validation loss. Counter: 16/50
# Epoch 150/1000, Train loss: -0.1695, Validation loss: -0.0583
# No improvement in validation loss. Counter: 17/50
# Epoch 151/1000, Train loss: -0.1639, Validation loss: -0.0582
# No improvement in validation loss. Counter: 18/50
# Epoch 152/1000, Train loss: -0.1739, Validation loss: -0.0584
# No improvement in validation loss. Counter: 19/50
# Epoch 153/1000, Train loss: -0.1704, Validation loss: -0.0586
# No improvement in validation loss. Counter: 20/50
# Epoch 154/1000, Train loss: -0.1728, Validation loss: -0.0588
# No improvement in validation loss. Counter: 21/50
# Epoch 155/1000, Train loss: -0.1768, Validation loss: -0.0584
# No improvement in validation loss. Counter: 22/50
# Epoch 156/1000, Train loss: -0.1700, Validation loss: -0.0581
# No improvement in validation loss. Counter: 23/50
# Epoch 157/1000, Train loss: -0.1716, Validation loss: -0.0584
# No improvement in validation loss. Counter: 24/50
# Epoch 158/1000, Train loss: -0.1705, Validation loss: -0.0588
# No improvement in validation loss. Counter: 25/50
# Epoch 159/1000, Train loss: -0.1673, Validation loss: -0.0589
# No improvement in validation loss. Counter: 26/50
# Epoch 160/1000, Train loss: -0.1705, Validation loss: -0.0590
# No improvement in validation loss. Counter: 27/50
# Epoch 161/1000, Train loss: -0.1746, Validation loss: -0.0592
# No improvement in validation loss. Counter: 28/50
# Epoch 162/1000, Train loss: -0.1706, Validation loss: -0.0593
# No improvement in validation loss. Counter: 29/50
# Epoch 163/1000, Train loss: -0.1714, Validation loss: -0.0591
# No improvement in validation loss. Counter: 30/50
# Epoch 164/1000, Train loss: -0.1815, Validation loss: -0.0590
# No improvement in validation loss. Counter: 31/50
# Epoch 165/1000, Train loss: -0.1753, Validation loss: -0.0589
# No improvement in validation loss. Counter: 32/50
# Epoch 166/1000, Train loss: -0.1800, Validation loss: -0.0589
# No improvement in validation loss. Counter: 33/50
# Epoch 167/1000, Train loss: -0.1816, Validation loss: -0.0587
# No improvement in validation loss. Counter: 34/50
# Epoch 168/1000, Train loss: -0.1813, Validation loss: -0.0589
# No improvement in validation loss. Counter: 35/50
# Epoch 169/1000, Train loss: -0.1834, Validation loss: -0.0587
# No improvement in validation loss. Counter: 36/50
# Epoch 170/1000, Train loss: -0.1817, Validation loss: -0.0588
# No improvement in validation loss. Counter: 37/50
# Epoch 171/1000, Train loss: -0.1853, Validation loss: -0.0589
# No improvement in validation loss. Counter: 38/50
# Epoch 172/1000, Train loss: -0.1817, Validation loss: -0.0594
# No improvement in validation loss. Counter: 39/50
# Epoch 173/1000, Train loss: -0.1830, Validation loss: -0.0593
# No improvement in validation loss. Counter: 40/50
# Epoch 174/1000, Train loss: -0.1819, Validation loss: -0.0591
# No improvement in validation loss. Counter: 41/50
# Epoch 175/1000, Train loss: -0.1805, Validation loss: -0.0591
# No improvement in validation loss. Counter: 42/50
# Epoch 176/1000, Train loss: -0.1949, Validation loss: -0.0588
# No improvement in validation loss. Counter: 43/50
# Epoch 177/1000, Train loss: -0.1869, Validation loss: -0.0588
# No improvement in validation loss. Counter: 44/50
# Epoch 178/1000, Train loss: -0.1806, Validation loss: -0.0589
# No improvement in validation loss. Counter: 45/50
# Epoch 179/1000, Train loss: -0.1831, Validation loss: -0.0589
# No improvement in validation loss. Counter: 46/50
# Epoch 180/1000, Train loss: -0.1791, Validation loss: -0.0593
# No improvement in validation loss. Counter: 47/50
# Epoch 181/1000, Train loss: -0.1845, Validation loss: -0.0592
# No improvement in validation loss. Counter: 48/50
# Epoch 182/1000, Train loss: -0.1870, Validation loss: -0.0594
# No improvement in validation loss. Counter: 49/50
# Epoch 183/1000, Train loss: -0.1785, Validation loss: -0.0597
# Validation loss improved. Resetting counter.
# Epoch 184/1000, Train loss: -0.1903, Validation loss: -0.0597
# No improvement in validation loss. Counter: 1/50
# Epoch 185/1000, Train loss: -0.1922, Validation loss: -0.0598
# No improvement in validation loss. Counter: 2/50
# Epoch 186/1000, Train loss: -0.1944, Validation loss: -0.0596
# No improvement in validation loss. Counter: 3/50
# Epoch 187/1000, Train loss: -0.1937, Validation loss: -0.0599
# Validation loss improved. Resetting counter.
# Epoch 188/1000, Train loss: -0.1893, Validation loss: -0.0598
# No improvement in validation loss. Counter: 1/50
# Epoch 189/1000, Train loss: -0.1948, Validation loss: -0.0600
# Validation loss improved. Resetting counter.
# Epoch 190/1000, Train loss: -0.1916, Validation loss: -0.0602
# Validation loss improved. Resetting counter.
# Epoch 191/1000, Train loss: -0.1912, Validation loss: -0.0605
# Validation loss improved. Resetting counter.
# Epoch 192/1000, Train loss: -0.1865, Validation loss: -0.0607
# Validation loss improved. Resetting counter.
# Epoch 193/1000, Train loss: -0.1928, Validation loss: -0.0610
# Validation loss improved. Resetting counter.
# Epoch 194/1000, Train loss: -0.1915, Validation loss: -0.0611
# Validation loss improved. Resetting counter.
# Epoch 195/1000, Train loss: -0.1958, Validation loss: -0.0609
# No improvement in validation loss. Counter: 1/50
# Epoch 196/1000, Train loss: -0.1926, Validation loss: -0.0608
# No improvement in validation loss. Counter: 2/50
# Epoch 197/1000, Train loss: -0.1943, Validation loss: -0.0608
# No improvement in validation loss. Counter: 3/50
# Epoch 198/1000, Train loss: -0.1969, Validation loss: -0.0613
# Validation loss improved. Resetting counter.
# Epoch 199/1000, Train loss: -0.1961, Validation loss: -0.0611
# No improvement in validation loss. Counter: 1/50
# Epoch 200/1000, Train loss: -0.1926, Validation loss: -0.0610
# No improvement in validation loss. Counter: 2/50
# Epoch 201/1000, Train loss: -0.1987, Validation loss: -0.0610
# No improvement in validation loss. Counter: 3/50
# Epoch 202/1000, Train loss: -0.1940, Validation loss: -0.0607
# No improvement in validation loss. Counter: 4/50
# Epoch 203/1000, Train loss: -0.1998, Validation loss: -0.0609
# No improvement in validation loss. Counter: 5/50
# Epoch 204/1000, Train loss: -0.2022, Validation loss: -0.0610
# No improvement in validation loss. Counter: 6/50
# Epoch 205/1000, Train loss: -0.1982, Validation loss: -0.0611
# No improvement in validation loss. Counter: 7/50
# Epoch 206/1000, Train loss: -0.2021, Validation loss: -0.0612
# No improvement in validation loss. Counter: 8/50
# Epoch 207/1000, Train loss: -0.2007, Validation loss: -0.0612
# No improvement in validation loss. Counter: 9/50
# Epoch 208/1000, Train loss: -0.2035, Validation loss: -0.0614
# Validation loss improved. Resetting counter.
# Epoch 209/1000, Train loss: -0.2074, Validation loss: -0.0614
# No improvement in validation loss. Counter: 1/50
# Epoch 210/1000, Train loss: -0.2024, Validation loss: -0.0615
# No improvement in validation loss. Counter: 2/50
# Epoch 211/1000, Train loss: -0.2038, Validation loss: -0.0611
# No improvement in validation loss. Counter: 3/50
# Epoch 212/1000, Train loss: -0.1946, Validation loss: -0.0611
# No improvement in validation loss. Counter: 4/50
# Epoch 213/1000, Train loss: -0.2000, Validation loss: -0.0611
# No improvement in validation loss. Counter: 5/50
# Epoch 214/1000, Train loss: -0.1936, Validation loss: -0.0614
# No improvement in validation loss. Counter: 6/50
# Epoch 215/1000, Train loss: -0.2036, Validation loss: -0.0615
# No improvement in validation loss. Counter: 7/50
# Epoch 216/1000, Train loss: -0.2052, Validation loss: -0.0617
# Validation loss improved. Resetting counter.
# Epoch 217/1000, Train loss: -0.2095, Validation loss: -0.0617
# No improvement in validation loss. Counter: 1/50
# Epoch 218/1000, Train loss: -0.1943, Validation loss: -0.0617
# No improvement in validation loss. Counter: 2/50
# Epoch 219/1000, Train loss: -0.2053, Validation loss: -0.0618
# Validation loss improved. Resetting counter.
# Epoch 220/1000, Train loss: -0.2102, Validation loss: -0.0614
# No improvement in validation loss. Counter: 1/50
# Epoch 221/1000, Train loss: -0.2013, Validation loss: -0.0615
# No improvement in validation loss. Counter: 2/50
# Epoch 222/1000, Train loss: -0.2079, Validation loss: -0.0615
# No improvement in validation loss. Counter: 3/50
# Epoch 223/1000, Train loss: -0.2074, Validation loss: -0.0614
# No improvement in validation loss. Counter: 4/50
# Epoch 224/1000, Train loss: -0.2151, Validation loss: -0.0611
# No improvement in validation loss. Counter: 5/50
# Epoch 225/1000, Train loss: -0.2133, Validation loss: -0.0611
# No improvement in validation loss. Counter: 6/50
# Epoch 226/1000, Train loss: -0.2083, Validation loss: -0.0611
# No improvement in validation loss. Counter: 7/50
# Epoch 227/1000, Train loss: -0.2094, Validation loss: -0.0611
# No improvement in validation loss. Counter: 8/50
# Epoch 228/1000, Train loss: -0.2130, Validation loss: -0.0613
# No improvement in validation loss. Counter: 9/50
# Epoch 229/1000, Train loss: -0.2105, Validation loss: -0.0613
# No improvement in validation loss. Counter: 10/50
# Epoch 230/1000, Train loss: -0.2137, Validation loss: -0.0613
# No improvement in validation loss. Counter: 11/50
# Epoch 231/1000, Train loss: -0.2069, Validation loss: -0.0616
# No improvement in validation loss. Counter: 12/50
# Epoch 232/1000, Train loss: -0.2164, Validation loss: -0.0612
# No improvement in validation loss. Counter: 13/50
# Epoch 233/1000, Train loss: -0.2107, Validation loss: -0.0613
# No improvement in validation loss. Counter: 14/50
# Epoch 234/1000, Train loss: -0.2137, Validation loss: -0.0613
# No improvement in validation loss. Counter: 15/50
# Epoch 235/1000, Train loss: -0.2170, Validation loss: -0.0615
# No improvement in validation loss. Counter: 16/50
# Epoch 236/1000, Train loss: -0.2143, Validation loss: -0.0614
# No improvement in validation loss. Counter: 17/50
# Epoch 237/1000, Train loss: -0.2085, Validation loss: -0.0616
# No improvement in validation loss. Counter: 18/50
# Epoch 238/1000, Train loss: -0.2142, Validation loss: -0.0619
# No improvement in validation loss. Counter: 19/50
# Epoch 239/1000, Train loss: -0.2143, Validation loss: -0.0616
# No improvement in validation loss. Counter: 20/50
# Epoch 240/1000, Train loss: -0.2095, Validation loss: -0.0617
# No improvement in validation loss. Counter: 21/50
# Epoch 241/1000, Train loss: -0.2159, Validation loss: -0.0617
# No improvement in validation loss. Counter: 22/50
# Epoch 242/1000, Train loss: -0.2132, Validation loss: -0.0614
# No improvement in validation loss. Counter: 23/50
# Epoch 243/1000, Train loss: -0.2189, Validation loss: -0.0612
# No improvement in validation loss. Counter: 24/50
# Epoch 244/1000, Train loss: -0.2182, Validation loss: -0.0614
# No improvement in validation loss. Counter: 25/50
# Epoch 245/1000, Train loss: -0.2134, Validation loss: -0.0614
# No improvement in validation loss. Counter: 26/50
# Epoch 246/1000, Train loss: -0.2161, Validation loss: -0.0618
# No improvement in validation loss. Counter: 27/50
# Epoch 247/1000, Train loss: -0.2189, Validation loss: -0.0620
# Validation loss improved. Resetting counter.
# Epoch 248/1000, Train loss: -0.2200, Validation loss: -0.0620
# No improvement in validation loss. Counter: 1/50
# Epoch 249/1000, Train loss: -0.2201, Validation loss: -0.0620
# No improvement in validation loss. Counter: 2/50
# Epoch 250/1000, Train loss: -0.2177, Validation loss: -0.0620
# No improvement in validation loss. Counter: 3/50
# Epoch 251/1000, Train loss: -0.2193, Validation loss: -0.0620
# No improvement in validation loss. Counter: 4/50
# Epoch 252/1000, Train loss: -0.2208, Validation loss: -0.0623
# Validation loss improved. Resetting counter.
# Epoch 253/1000, Train loss: -0.2215, Validation loss: -0.0621
# No improvement in validation loss. Counter: 1/50
# Epoch 254/1000, Train loss: -0.2220, Validation loss: -0.0620
# No improvement in validation loss. Counter: 2/50
# Epoch 255/1000, Train loss: -0.2218, Validation loss: -0.0618
# No improvement in validation loss. Counter: 3/50
# Epoch 256/1000, Train loss: -0.2224, Validation loss: -0.0618
# No improvement in validation loss. Counter: 4/50
# Epoch 257/1000, Train loss: -0.2224, Validation loss: -0.0620
# No improvement in validation loss. Counter: 5/50
# Epoch 258/1000, Train loss: -0.2158, Validation loss: -0.0620
# No improvement in validation loss. Counter: 6/50
# Epoch 259/1000, Train loss: -0.2263, Validation loss: -0.0619
# No improvement in validation loss. Counter: 7/50
# Epoch 260/1000, Train loss: -0.2277, Validation loss: -0.0620
# No improvement in validation loss. Counter: 8/50
# Epoch 261/1000, Train loss: -0.2227, Validation loss: -0.0619
# No improvement in validation loss. Counter: 9/50
# Epoch 262/1000, Train loss: -0.2291, Validation loss: -0.0619
# No improvement in validation loss. Counter: 10/50
# Epoch 263/1000, Train loss: -0.2275, Validation loss: -0.0616
# No improvement in validation loss. Counter: 11/50
# Epoch 264/1000, Train loss: -0.2261, Validation loss: -0.0617
# No improvement in validation loss. Counter: 12/50
# Epoch 265/1000, Train loss: -0.2295, Validation loss: -0.0616
# No improvement in validation loss. Counter: 13/50
# Epoch 266/1000, Train loss: -0.2236, Validation loss: -0.0615
# No improvement in validation loss. Counter: 14/50
# Epoch 267/1000, Train loss: -0.2247, Validation loss: -0.0617
# No improvement in validation loss. Counter: 15/50
# Epoch 268/1000, Train loss: -0.2314, Validation loss: -0.0619
# No improvement in validation loss. Counter: 16/50
# Epoch 269/1000, Train loss: -0.2297, Validation loss: -0.0619
# No improvement in validation loss. Counter: 17/50
# Epoch 270/1000, Train loss: -0.2318, Validation loss: -0.0622
# No improvement in validation loss. Counter: 18/50
# Epoch 271/1000, Train loss: -0.2297, Validation loss: -0.0624
# Validation loss improved. Resetting counter.
# Epoch 272/1000, Train loss: -0.2288, Validation loss: -0.0622
# No improvement in validation loss. Counter: 1/50
# Epoch 273/1000, Train loss: -0.2346, Validation loss: -0.0621
# No improvement in validation loss. Counter: 2/50
# Epoch 274/1000, Train loss: -0.2307, Validation loss: -0.0620
# No improvement in validation loss. Counter: 3/50
# Epoch 275/1000, Train loss: -0.2334, Validation loss: -0.0621
# No improvement in validation loss. Counter: 4/50
# Epoch 276/1000, Train loss: -0.2303, Validation loss: -0.0620
# No improvement in validation loss. Counter: 5/50
# Epoch 277/1000, Train loss: -0.2245, Validation loss: -0.0622
# No improvement in validation loss. Counter: 6/50
# Epoch 278/1000, Train loss: -0.2337, Validation loss: -0.0622
# No improvement in validation loss. Counter: 7/50
# Epoch 279/1000, Train loss: -0.2269, Validation loss: -0.0627
# Validation loss improved. Resetting counter.
# Epoch 280/1000, Train loss: -0.2302, Validation loss: -0.0626
# No improvement in validation loss. Counter: 1/50
# Epoch 281/1000, Train loss: -0.2330, Validation loss: -0.0628
# Validation loss improved. Resetting counter.
# Epoch 282/1000, Train loss: -0.2346, Validation loss: -0.0632
# Validation loss improved. Resetting counter.
# Epoch 283/1000, Train loss: -0.2361, Validation loss: -0.0632
# No improvement in validation loss. Counter: 1/50
# Epoch 284/1000, Train loss: -0.2357, Validation loss: -0.0629
# No improvement in validation loss. Counter: 2/50
# Epoch 285/1000, Train loss: -0.2361, Validation loss: -0.0632
# No improvement in validation loss. Counter: 3/50
# Epoch 286/1000, Train loss: -0.2381, Validation loss: -0.0632
# No improvement in validation loss. Counter: 4/50
# Epoch 287/1000, Train loss: -0.2412, Validation loss: -0.0632
# No improvement in validation loss. Counter: 5/50
# Epoch 288/1000, Train loss: -0.2327, Validation loss: -0.0632
# No improvement in validation loss. Counter: 6/50
# Epoch 289/1000, Train loss: -0.2323, Validation loss: -0.0633
# No improvement in validation loss. Counter: 7/50
# Epoch 290/1000, Train loss: -0.2360, Validation loss: -0.0635
# Validation loss improved. Resetting counter.
# Epoch 291/1000, Train loss: -0.2287, Validation loss: -0.0637
# Validation loss improved. Resetting counter.
# Epoch 292/1000, Train loss: -0.2345, Validation loss: -0.0637
# No improvement in validation loss. Counter: 1/50
# Epoch 293/1000, Train loss: -0.2406, Validation loss: -0.0639
# Validation loss improved. Resetting counter.
# Epoch 294/1000, Train loss: -0.2402, Validation loss: -0.0639
# No improvement in validation loss. Counter: 1/50
# Epoch 295/1000, Train loss: -0.2384, Validation loss: -0.0639
# No improvement in validation loss. Counter: 2/50
# Epoch 296/1000, Train loss: -0.2433, Validation loss: -0.0640
# Validation loss improved. Resetting counter.
# Epoch 297/1000, Train loss: -0.2381, Validation loss: -0.0639
# No improvement in validation loss. Counter: 1/50
# Epoch 298/1000, Train loss: -0.2344, Validation loss: -0.0641
# No improvement in validation loss. Counter: 2/50
# Epoch 299/1000, Train loss: -0.2439, Validation loss: -0.0640
# No improvement in validation loss. Counter: 3/50
# Epoch 300/1000, Train loss: -0.2404, Validation loss: -0.0642
# Validation loss improved. Resetting counter.
# Epoch 301/1000, Train loss: -0.2357, Validation loss: -0.0638
# No improvement in validation loss. Counter: 1/50
# Epoch 302/1000, Train loss: -0.2410, Validation loss: -0.0644
# Validation loss improved. Resetting counter.
# Epoch 303/1000, Train loss: -0.2370, Validation loss: -0.0646
# Validation loss improved. Resetting counter.
# Epoch 304/1000, Train loss: -0.2376, Validation loss: -0.0644
# No improvement in validation loss. Counter: 1/50
# Epoch 305/1000, Train loss: -0.2447, Validation loss: -0.0644
# No improvement in validation loss. Counter: 2/50
# Epoch 306/1000, Train loss: -0.2387, Validation loss: -0.0643
# No improvement in validation loss. Counter: 3/50
# Epoch 307/1000, Train loss: -0.2465, Validation loss: -0.0641
# No improvement in validation loss. Counter: 4/50
# Epoch 308/1000, Train loss: -0.2465, Validation loss: -0.0643
# No improvement in validation loss. Counter: 5/50
# Epoch 309/1000, Train loss: -0.2401, Validation loss: -0.0644
# No improvement in validation loss. Counter: 6/50
# Epoch 310/1000, Train loss: -0.2508, Validation loss: -0.0643
# No improvement in validation loss. Counter: 7/50
# Epoch 311/1000, Train loss: -0.2476, Validation loss: -0.0642
# No improvement in validation loss. Counter: 8/50
# Epoch 312/1000, Train loss: -0.2481, Validation loss: -0.0641
# No improvement in validation loss. Counter: 9/50
# Epoch 313/1000, Train loss: -0.2399, Validation loss: -0.0644
# No improvement in validation loss. Counter: 10/50
# Epoch 314/1000, Train loss: -0.2508, Validation loss: -0.0643
# No improvement in validation loss. Counter: 11/50
# Epoch 315/1000, Train loss: -0.2399, Validation loss: -0.0647
# Validation loss improved. Resetting counter.
# Epoch 316/1000, Train loss: -0.2490, Validation loss: -0.0648
# Validation loss improved. Resetting counter.
# Epoch 317/1000, Train loss: -0.2492, Validation loss: -0.0644
# No improvement in validation loss. Counter: 1/50
# Epoch 318/1000, Train loss: -0.2537, Validation loss: -0.0643
# No improvement in validation loss. Counter: 2/50
# Epoch 319/1000, Train loss: -0.2467, Validation loss: -0.0643
# No improvement in validation loss. Counter: 3/50
# Epoch 320/1000, Train loss: -0.2454, Validation loss: -0.0642
# No improvement in validation loss. Counter: 4/50
# Epoch 321/1000, Train loss: -0.2454, Validation loss: -0.0646
# No improvement in validation loss. Counter: 5/50
# Epoch 322/1000, Train loss: -0.2487, Validation loss: -0.0646
# No improvement in validation loss. Counter: 6/50
# Epoch 323/1000, Train loss: -0.2545, Validation loss: -0.0647
# No improvement in validation loss. Counter: 7/50
# Epoch 324/1000, Train loss: -0.2476, Validation loss: -0.0645
# No improvement in validation loss. Counter: 8/50
# Epoch 325/1000, Train loss: -0.2540, Validation loss: -0.0647
# No improvement in validation loss. Counter: 9/50
# Epoch 326/1000, Train loss: -0.2557, Validation loss: -0.0646
# No improvement in validation loss. Counter: 10/50
# Epoch 327/1000, Train loss: -0.2542, Validation loss: -0.0644
# No improvement in validation loss. Counter: 11/50
# Epoch 328/1000, Train loss: -0.2502, Validation loss: -0.0647
# No improvement in validation loss. Counter: 12/50
# Epoch 329/1000, Train loss: -0.2547, Validation loss: -0.0649
# No improvement in validation loss. Counter: 13/50
# Epoch 330/1000, Train loss: -0.2492, Validation loss: -0.0649
# No improvement in validation loss. Counter: 14/50
# Epoch 331/1000, Train loss: -0.2526, Validation loss: -0.0651
# Validation loss improved. Resetting counter.
# Epoch 332/1000, Train loss: -0.2534, Validation loss: -0.0652
# No improvement in validation loss. Counter: 1/50
# Epoch 333/1000, Train loss: -0.2544, Validation loss: -0.0651
# No improvement in validation loss. Counter: 2/50
# Epoch 334/1000, Train loss: -0.2606, Validation loss: -0.0651
# No improvement in validation loss. Counter: 3/50
# Epoch 335/1000, Train loss: -0.2515, Validation loss: -0.0647
# No improvement in validation loss. Counter: 4/50
# Epoch 336/1000, Train loss: -0.2551, Validation loss: -0.0648
# No improvement in validation loss. Counter: 5/50
# Epoch 337/1000, Train loss: -0.2483, Validation loss: -0.0651
# No improvement in validation loss. Counter: 6/50
# Epoch 338/1000, Train loss: -0.2550, Validation loss: -0.0650
# No improvement in validation loss. Counter: 7/50
# Epoch 339/1000, Train loss: -0.2505, Validation loss: -0.0646
# No improvement in validation loss. Counter: 8/50
# Epoch 340/1000, Train loss: -0.2577, Validation loss: -0.0646
# No improvement in validation loss. Counter: 9/50
# Epoch 341/1000, Train loss: -0.2633, Validation loss: -0.0649
# No improvement in validation loss. Counter: 10/50
# Epoch 342/1000, Train loss: -0.2484, Validation loss: -0.0654
# Validation loss improved. Resetting counter.
# Epoch 343/1000, Train loss: -0.2550, Validation loss: -0.0649
# No improvement in validation loss. Counter: 1/50
# Epoch 344/1000, Train loss: -0.2568, Validation loss: -0.0653
# No improvement in validation loss. Counter: 2/50
# Epoch 345/1000, Train loss: -0.2571, Validation loss: -0.0656
# Validation loss improved. Resetting counter.
# Epoch 346/1000, Train loss: -0.2585, Validation loss: -0.0653
# No improvement in validation loss. Counter: 1/50
# Epoch 347/1000, Train loss: -0.2598, Validation loss: -0.0653
# No improvement in validation loss. Counter: 2/50
# Epoch 348/1000, Train loss: -0.2638, Validation loss: -0.0655
# No improvement in validation loss. Counter: 3/50
# Epoch 349/1000, Train loss: -0.2589, Validation loss: -0.0653
# No improvement in validation loss. Counter: 4/50
# Epoch 350/1000, Train loss: -0.2564, Validation loss: -0.0656
# No improvement in validation loss. Counter: 5/50
# Epoch 351/1000, Train loss: -0.2622, Validation loss: -0.0656
# No improvement in validation loss. Counter: 6/50
# Epoch 352/1000, Train loss: -0.2643, Validation loss: -0.0656
# No improvement in validation loss. Counter: 7/50
# Epoch 353/1000, Train loss: -0.2531, Validation loss: -0.0659
# Validation loss improved. Resetting counter.
# Epoch 354/1000, Train loss: -0.2551, Validation loss: -0.0662
# Validation loss improved. Resetting counter.
# Epoch 355/1000, Train loss: -0.2582, Validation loss: -0.0665
# Validation loss improved. Resetting counter.
# Epoch 356/1000, Train loss: -0.2548, Validation loss: -0.0663
# No improvement in validation loss. Counter: 1/50
# Epoch 357/1000, Train loss: -0.2570, Validation loss: -0.0664
# No improvement in validation loss. Counter: 2/50
# Epoch 358/1000, Train loss: -0.2602, Validation loss: -0.0664
# No improvement in validation loss. Counter: 3/50
# Epoch 359/1000, Train loss: -0.2641, Validation loss: -0.0659
# No improvement in validation loss. Counter: 4/50
# Epoch 360/1000, Train loss: -0.2505, Validation loss: -0.0659
# No improvement in validation loss. Counter: 5/50
# Epoch 361/1000, Train loss: -0.2609, Validation loss: -0.0658
# No improvement in validation loss. Counter: 6/50
# Epoch 362/1000, Train loss: -0.2647, Validation loss: -0.0659
# No improvement in validation loss. Counter: 7/50
# Epoch 363/1000, Train loss: -0.2577, Validation loss: -0.0662
# No improvement in validation loss. Counter: 8/50
# Epoch 364/1000, Train loss: -0.2633, Validation loss: -0.0663
# No improvement in validation loss. Counter: 9/50
# Epoch 365/1000, Train loss: -0.2613, Validation loss: -0.0664
# No improvement in validation loss. Counter: 10/50
# Epoch 366/1000, Train loss: -0.2643, Validation loss: -0.0664
# No improvement in validation loss. Counter: 11/50
# Epoch 367/1000, Train loss: -0.2613, Validation loss: -0.0665
# No improvement in validation loss. Counter: 12/50
# Epoch 368/1000, Train loss: -0.2616, Validation loss: -0.0665
# No improvement in validation loss. Counter: 13/50
# Epoch 369/1000, Train loss: -0.2695, Validation loss: -0.0665
# No improvement in validation loss. Counter: 14/50
# Epoch 370/1000, Train loss: -0.2634, Validation loss: -0.0667
# Validation loss improved. Resetting counter.
# Epoch 371/1000, Train loss: -0.2631, Validation loss: -0.0664
# No improvement in validation loss. Counter: 1/50
# Epoch 372/1000, Train loss: -0.2698, Validation loss: -0.0663
# No improvement in validation loss. Counter: 2/50
# Epoch 373/1000, Train loss: -0.2641, Validation loss: -0.0659
# No improvement in validation loss. Counter: 3/50
# Epoch 374/1000, Train loss: -0.2662, Validation loss: -0.0665
# No improvement in validation loss. Counter: 4/50
# Epoch 375/1000, Train loss: -0.2658, Validation loss: -0.0671
# Validation loss improved. Resetting counter.
# Epoch 376/1000, Train loss: -0.2661, Validation loss: -0.0669
# No improvement in validation loss. Counter: 1/50
# Epoch 377/1000, Train loss: -0.2680, Validation loss: -0.0670
# No improvement in validation loss. Counter: 2/50
# Epoch 378/1000, Train loss: -0.2701, Validation loss: -0.0667
# No improvement in validation loss. Counter: 3/50
# Epoch 379/1000, Train loss: -0.2666, Validation loss: -0.0667
# No improvement in validation loss. Counter: 4/50
# Epoch 380/1000, Train loss: -0.2653, Validation loss: -0.0667
# No improvement in validation loss. Counter: 5/50
# Epoch 381/1000, Train loss: -0.2711, Validation loss: -0.0668
# No improvement in validation loss. Counter: 6/50
# Epoch 382/1000, Train loss: -0.2659, Validation loss: -0.0670
# No improvement in validation loss. Counter: 7/50
# Epoch 383/1000, Train loss: -0.2670, Validation loss: -0.0674
# Validation loss improved. Resetting counter.
# Epoch 384/1000, Train loss: -0.2697, Validation loss: -0.0670
# No improvement in validation loss. Counter: 1/50
# Epoch 385/1000, Train loss: -0.2668, Validation loss: -0.0670
# No improvement in validation loss. Counter: 2/50
# Epoch 386/1000, Train loss: -0.2694, Validation loss: -0.0671
# No improvement in validation loss. Counter: 3/50
# Epoch 387/1000, Train loss: -0.2703, Validation loss: -0.0672
# No improvement in validation loss. Counter: 4/50
# Epoch 388/1000, Train loss: -0.2745, Validation loss: -0.0673
# No improvement in validation loss. Counter: 5/50
# Epoch 389/1000, Train loss: -0.2702, Validation loss: -0.0675
# Validation loss improved. Resetting counter.
# Epoch 390/1000, Train loss: -0.2740, Validation loss: -0.0677
# Validation loss improved. Resetting counter.
# Epoch 391/1000, Train loss: -0.2705, Validation loss: -0.0675
# No improvement in validation loss. Counter: 1/50
# Epoch 392/1000, Train loss: -0.2732, Validation loss: -0.0673
# No improvement in validation loss. Counter: 2/50
# Epoch 393/1000, Train loss: -0.2723, Validation loss: -0.0668
# No improvement in validation loss. Counter: 3/50
# Epoch 394/1000, Train loss: -0.2661, Validation loss: -0.0670
# No improvement in validation loss. Counter: 4/50
# Epoch 395/1000, Train loss: -0.2692, Validation loss: -0.0673
# No improvement in validation loss. Counter: 5/50
# Epoch 396/1000, Train loss: -0.2724, Validation loss: -0.0671
# No improvement in validation loss. Counter: 6/50
# Epoch 397/1000, Train loss: -0.2761, Validation loss: -0.0674
# No improvement in validation loss. Counter: 7/50
# Epoch 398/1000, Train loss: -0.2703, Validation loss: -0.0670
# No improvement in validation loss. Counter: 8/50
# Epoch 399/1000, Train loss: -0.2775, Validation loss: -0.0669
# No improvement in validation loss. Counter: 9/50
# Epoch 400/1000, Train loss: -0.2678, Validation loss: -0.0668
# No improvement in validation loss. Counter: 10/50
# Epoch 401/1000, Train loss: -0.2708, Validation loss: -0.0671
# No improvement in validation loss. Counter: 11/50
# Epoch 402/1000, Train loss: -0.2717, Validation loss: -0.0674
# No improvement in validation loss. Counter: 12/50
# Epoch 403/1000, Train loss: -0.2701, Validation loss: -0.0674
# No improvement in validation loss. Counter: 13/50
# Epoch 404/1000, Train loss: -0.2725, Validation loss: -0.0678
# No improvement in validation loss. Counter: 14/50
# Epoch 405/1000, Train loss: -0.2741, Validation loss: -0.0680
# Validation loss improved. Resetting counter.
# Epoch 406/1000, Train loss: -0.2784, Validation loss: -0.0679
# No improvement in validation loss. Counter: 1/50
# Epoch 407/1000, Train loss: -0.2749, Validation loss: -0.0673
# No improvement in validation loss. Counter: 2/50
# Epoch 408/1000, Train loss: -0.2769, Validation loss: -0.0673
# No improvement in validation loss. Counter: 3/50
# Epoch 409/1000, Train loss: -0.2756, Validation loss: -0.0678
# No improvement in validation loss. Counter: 4/50
# Epoch 410/1000, Train loss: -0.2727, Validation loss: -0.0675
# No improvement in validation loss. Counter: 5/50
# Epoch 411/1000, Train loss: -0.2754, Validation loss: -0.0674
# No improvement in validation loss. Counter: 6/50
# Epoch 412/1000, Train loss: -0.2778, Validation loss: -0.0678
# No improvement in validation loss. Counter: 7/50
# Epoch 413/1000, Train loss: -0.2731, Validation loss: -0.0671
# No improvement in validation loss. Counter: 8/50
# Epoch 414/1000, Train loss: -0.2701, Validation loss: -0.0669
# No improvement in validation loss. Counter: 9/50
# Epoch 415/1000, Train loss: -0.2704, Validation loss: -0.0669
# No improvement in validation loss. Counter: 10/50
# Epoch 416/1000, Train loss: -0.2797, Validation loss: -0.0670
# No improvement in validation loss. Counter: 11/50
# Epoch 417/1000, Train loss: -0.2808, Validation loss: -0.0673
# No improvement in validation loss. Counter: 12/50
# Epoch 418/1000, Train loss: -0.2801, Validation loss: -0.0673
# No improvement in validation loss. Counter: 13/50
# Epoch 419/1000, Train loss: -0.2810, Validation loss: -0.0676
# No improvement in validation loss. Counter: 14/50
# Epoch 420/1000, Train loss: -0.2818, Validation loss: -0.0679
# No improvement in validation loss. Counter: 15/50
# Epoch 421/1000, Train loss: -0.2764, Validation loss: -0.0674
# No improvement in validation loss. Counter: 16/50
# Epoch 422/1000, Train loss: -0.2750, Validation loss: -0.0672
# No improvement in validation loss. Counter: 17/50
# Epoch 423/1000, Train loss: -0.2783, Validation loss: -0.0674
# No improvement in validation loss. Counter: 18/50
# Epoch 424/1000, Train loss: -0.2851, Validation loss: -0.0675
# No improvement in validation loss. Counter: 19/50
# Epoch 425/1000, Train loss: -0.2836, Validation loss: -0.0674
# No improvement in validation loss. Counter: 20/50
# Epoch 426/1000, Train loss: -0.2788, Validation loss: -0.0674
# No improvement in validation loss. Counter: 21/50
# Epoch 427/1000, Train loss: -0.2764, Validation loss: -0.0677
# No improvement in validation loss. Counter: 22/50
# Epoch 428/1000, Train loss: -0.2818, Validation loss: -0.0677
# No improvement in validation loss. Counter: 23/50
# Epoch 429/1000, Train loss: -0.2846, Validation loss: -0.0677
# No improvement in validation loss. Counter: 24/50
# Epoch 430/1000, Train loss: -0.2840, Validation loss: -0.0675
# No improvement in validation loss. Counter: 25/50
# Epoch 431/1000, Train loss: -0.2794, Validation loss: -0.0673
# No improvement in validation loss. Counter: 26/50
# Epoch 432/1000, Train loss: -0.2806, Validation loss: -0.0674
# No improvement in validation loss. Counter: 27/50
# Epoch 433/1000, Train loss: -0.2823, Validation loss: -0.0674
# No improvement in validation loss. Counter: 28/50
# Epoch 434/1000, Train loss: -0.2806, Validation loss: -0.0674
# No improvement in validation loss. Counter: 29/50
# Epoch 435/1000, Train loss: -0.2745, Validation loss: -0.0675
# No improvement in validation loss. Counter: 30/50
# Epoch 436/1000, Train loss: -0.2769, Validation loss: -0.0673
# No improvement in validation loss. Counter: 31/50
# Epoch 437/1000, Train loss: -0.2849, Validation loss: -0.0675
# No improvement in validation loss. Counter: 32/50
# Epoch 438/1000, Train loss: -0.2803, Validation loss: -0.0671
# No improvement in validation loss. Counter: 33/50
# Epoch 439/1000, Train loss: -0.2909, Validation loss: -0.0668
# No improvement in validation loss. Counter: 34/50
# Epoch 440/1000, Train loss: -0.2808, Validation loss: -0.0666
# No improvement in validation loss. Counter: 35/50
# Epoch 441/1000, Train loss: -0.2824, Validation loss: -0.0664
# No improvement in validation loss. Counter: 36/50
# Epoch 442/1000, Train loss: -0.2814, Validation loss: -0.0665
# No improvement in validation loss. Counter: 37/50
# Epoch 443/1000, Train loss: -0.2840, Validation loss: -0.0666
# No improvement in validation loss. Counter: 38/50
# Epoch 444/1000, Train loss: -0.2849, Validation loss: -0.0666
# No improvement in validation loss. Counter: 39/50
# Epoch 445/1000, Train loss: -0.2805, Validation loss: -0.0663
# No improvement in validation loss. Counter: 40/50
# Epoch 446/1000, Train loss: -0.2820, Validation loss: -0.0664
# No improvement in validation loss. Counter: 41/50
# Epoch 447/1000, Train loss: -0.2870, Validation loss: -0.0663
# No improvement in validation loss. Counter: 42/50
# Epoch 448/1000, Train loss: -0.2813, Validation loss: -0.0664
# No improvement in validation loss. Counter: 43/50
# Epoch 449/1000, Train loss: -0.2883, Validation loss: -0.0664
# No improvement in validation loss. Counter: 44/50
# Epoch 450/1000, Train loss: -0.2893, Validation loss: -0.0665
# No improvement in validation loss. Counter: 45/50
# Epoch 451/1000, Train loss: -0.2880, Validation loss: -0.0659
# No improvement in validation loss. Counter: 46/50
# Epoch 452/1000, Train loss: -0.2836, Validation loss: -0.0660
# No improvement in validation loss. Counter: 47/50
# Epoch 453/1000, Train loss: -0.2823, Validation loss: -0.0659
# No improvement in validation loss. Counter: 48/50
# Epoch 454/1000, Train loss: -0.2825, Validation loss: -0.0666
# No improvement in validation loss. Counter: 49/50
# Epoch 455/1000, Train loss: -0.2873, Validation loss: -0.0658
# No improvement in validation loss. Counter: 50/50
# Early stopping triggered!
# /var/folders/b5/1m52fctd69x96lfkwk5lv46m0000gn/T/ipykernel_71501/2849933634.py:67: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(savepath))

# %%
port_ret = np.array(test_y) * np.array(y_pred)
port_ret = np.sum(port_ret, axis=1)
port_cumret = np.cumsum(port_ret)

# %%
print(report_metrics(port_ret))
# Out:
# {'annual_ret': np.float64(0.04746514789987081), 'annual_std': np.float64(0.3000755735152593), 'annual_sharpe': np.float64(0.15817731294765694)}

# %%
plt.figure(figsize=(10, 6))
plt.plot(port_cumret, label="MLP")
plt.xlabel("Date")
plt.ylabel("Cumulative Return")
plt.legend()
plt.show()
